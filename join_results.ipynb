# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option("display.max_colwidth", 200)
import json
from glob import glob
from tqdm.auto import tqdm
import os
files = glob("results/*.json")
len(files)
# Out:
# 301

# %%
results = []
for filename in tqdm(files):
    with open(filename) as f:
        try:
            data = json.load(f)
        except:
            print(f"Can't read {filename}")
            continue
            #os.remove(filename)
    data["AI_description"] = data["description"]
    metadata = filename.replace("results/", "videos/").replace(".result.json", ".info.json")
    with open(metadata) as f:
        meta = json.load(f)
    keys = ['id', 'extractor', 'channel', 'channel_id', 'uploader', 'uploader_id', 'title', 'description', 'timestamp', 'view_count', 'like_count', 'comment_count', 'duration', 'upload_date', 'webpage_url']
    for key in keys:
        data[key] = meta.get(key, None)
    results.append(data)
df = pd.DataFrame(results).sort_values("upload_date")
df
# Out:
#   0%|          | 0/301 [00:00<?, ?it/s]
# Can't read results/Video by bronlewiscomedy [DF13b83zCu8].result.json
# Can't read results/Part1 When my parents left, my babysitter asked, Where’s your timeout... [7557547762980637965].result.json
# Can't read results/Video by annamariemontessori [DNTJU3YR9l4].result.json
# Can't read results/Video by mamasamurai__ [DLMnmPksV8V].result.json
# Can't read results/Membalas @it's.me_wita   Koreksi hutang balance (budget = actual) unt... [7380994866991402245].result.json
# Can't read results/Timeouts aren’t just strategy they’re moments to lead, empower, and e... [7517356090787368223].result.json
# Can't read results/“Would it help you to go to your positive time out den until you feel... [7190106856449117446].result.json
# Can't read results/#gadelmaleh #cambriolage�� #montre [7180516596849364230].result.json
#                                            description  \
# 63   #timeout #momsoftiktok #break #parenting #duet...
# 249  Nikki Mullen-Cruz’s “cool-down corner” for her...
# 146  Time outs.... 😬.. #tiktoktherapist #discipline...
# 147  Reply to @audreyhernandez00 #tiktoktherapist #...
# 49   Effectively using timeouts. #tiktoktherapist #...
# ..                                                 ...
# 237  parenting 🫣 #timeout #parenting #singlemum #em...
# 35
# 155  (Episode 7) Positive Behavior Support  101\n\n...
# 287  Time-outs are a common discipline strategy for...
# 107  The best local & breaking news source in the U...
#
#                                             transcript  \
# 63   As no one's giving you... You supposed to be b...
# 249  After about a year, I made a choice to do away...
# 146  Today I want to talk about timeouts. A few yea...
# 147  Time outs are an effective form of discipline....
# 49   how to effectively use timeouts. If you haven'...
# ..                                                 ...
# 237  So, I'm not sure what this says about my paren...
# 35   Audrey, how many times do I say don't drop kic...
# 155  stop making this personal. Like if they do wha...
# 287                                  No spoken content
# 107                                  No spoken content
#
#                                                   tone  timeout language  \
# 63                                            Humorous     True  English
# 249                           Educational and positive     True  English
# 146                        Educational and informative     True  English
# 147                                        Educational     True  English
# 49                                         Educational     True  English
# ..                                                 ...      ...      ...
# 237                                          Emotional     True  English
# 35   The tone of the video is humorous and comedic,...     True  English
# 155                                        Educational    False  English
# 287                                        Educational     True  English
# 107                                           Humorous     True  English
#
#                                              marketing    ASD   ADHD  anxiety  \
# 63                                No marketing content  False  False    False
# 249                                                GMA  False  False     True
# 146                               No marketing content  False  False    False
# 147                               No marketing content  False  False    False
# 49                                No marketing content  False  False    False
# ..                                                 ...    ...    ...      ...
# 237                               No marketing content  False  False    False
# 35                                No marketing content  False  False    False
# 155                               No marketing content  False  False    False
# 287  Yes, it is promoting the brand 'Little Roots L...  False  False    False
# 107                               No marketing content  False  False    False
#
#                                               job sentiment  \
# 63                    content creator, influencer   neutral
# 249                               content creator  negative
# 146                    therapist, content creator  positive
# 147                    therapist, content creator   neutral
# 49                     therapist, content creator  positive
# ..                                            ...       ...
# 237                               content creator  negative
# 35                                      professor  negative
# 155  therapist, counselor, coach, content creator  negative
# 287                               content creator  negative
# 107                               content creator   neutral
#
#                                              criticism  \
# 63   Concerns about emotional or social development...
# 249  Concerns about emotional or social development...
# 146           Concerns about practicality or usability
# 147  Concerns about emotional or social development...
# 49
# ..                                                 ...
# 237  Concerns about emotional or social development...
# 35   Concerns about physical safety – child, Concer...
# 155  Concerns about emotional or social development...
# 287   Concerns about relational quality – parent-child
# 107
#
#                                 alternative_strategies  usefulness  \
# 63                 No alternative strategies mentioned           5
# 249                                     calming corner           9
# 146                No alternative strategies mentioned           9
# 147  setting limits, using distraction, redirecting...           8
# 49   connect with them relationally, talk about how...           9
# ..                                                 ...         ...
# 237                No alternative strategies mentioned           6
# 35                 No alternative strategies mentioned           2
# 155  Effective praise, Tangible/ token economies, R...           8
# 287  Time-In (sit together & talk), Calm Corner (qu...           9
# 107                No alternative strategies mentioned           3
#
#      misleading  quality                                personal_experience  \
# 63            5        6  The speaker states that the corner she is in i...
# 249           2        8  Yes, the speaker, Nikki Mullen-Cruz, shares th...
# 146           2        8                   No personal experience mentioned
# 147           2        7                   No personal experience mentioned
# 49            2        8                   No personal experience mentioned
# ..          ...      ...                                                ...
# 237           2        7  The speaker recounts a recent experience where...
# 35            8        3                   No personal experience mentioned
# 155           2        7                   No personal experience mentioned
# 287           2        8                                 No job information
# 107           5        6                   No personal experience mentioned
#
#                                         AI_description                   id  \
# 63   A woman with blonde hair, wearing a blue t-shi...  6843892180726156549
# 249  The video is a news segment from 'Good Morning...          yZjFQycWOck
# 146  A man, identified as Ryan Allen, is speaking d...  6860565005973196038
# 147  A man in a pink collared shirt is speaking dir...  6860942327783918853
# 49   A man, identified as Ryan Allen, is speaking d...  6886504627844517126
# ..                                                 ...                  ...
# 237  A woman with blue eyes and dark hair is speaki...  7558176270933036310
# 35   The video shows a large audience in an auditor...          YU675pDerFA
# 155  The video is a static presentation slide for a...          A2zNQFlQI-E
# 287  The video is an animated infographic that disc...          EToVYYeI3Ao
# 107  The video shows a woman in a white robe sweepi...              default
#
#     extractor                               channel  \
# 63     TikTok                              Jennifer
# 249   youtube                  Good Morning America
# 146    TikTok                            Ryan Allen
# 147    TikTok                            Ryan Allen
# 49     TikTok                            Ryan Allen
# ..        ...                                   ...
# 237    TikTok                             georgina🤍
# 35    youtube                          Edward Jones
# 155   youtube  Talks Too Much with Jill Anne Castle
# 287   youtube                      Little Roots Lab
# 107   generic                                  None
#
#                                             channel_id  \
# 63   MS4wLjABAAAAInU1rpIYXdOwIlVRwmo4GdzYPSXgcze8Xc...
# 249                           UCH1oRy1dINbMVp3UFWrKP0w
# 146  MS4wLjABAAAAE7X7c7vQEb9cfNGi1j3BYJ5AiE2JCzhjWm...
# 147  MS4wLjABAAAAE7X7c7vQEb9cfNGi1j3BYJ5AiE2JCzhjWm...
# 49   MS4wLjABAAAAE7X7c7vQEb9cfNGi1j3BYJ5AiE2JCzhjWm...
# ..                                                 ...
# 237  MS4wLjABAAAApe0rfpqEhfC52myFi7dyCVeSm9AIjnfuzg...
# 35                            UCX_N4yOLBH2a8gDw0i5Oeew
# 155                           UCK181s-r4GwFkBl3ezyOqrg
# 287                           UCscggFYoDOyAVeiKZ0ESSpA
# 107                                               None
#
#                                  uploader          uploader_id  \
# 63                      jennifer_nicole26  6620483940443766789
# 249                  Good Morning America                 @GMA
# 146                      preschooltherapy  6841301207401038853
# 147                      preschooltherapy  6841301207401038853
# 49                       preschooltherapy  6841301207401038853
# ..                                    ...                  ...
# 237                            georgeox97  6807895399819478021
# 35                           Edward Jones           @Joe-n2q1k
# 155  Talks Too Much with Jill Anne Castle      @jillannecastle
# 287                      Little Roots Lab      @LittleRootsLab
# 107                     www.newsbreak.com                 None
#
#                                                  title     timestamp  \
# 63   #timeout #momsoftiktok #break #parenting #duet...  1.593468e+09
# 249  Mom’s alternative to timeout is taking over Ti...  1.596449e+09
# 146  Time outs.... 😬.. #tiktoktherapist #discipline...  1.597350e+09
# 147  Reply to @audreyhernandez00 #tiktoktherapist #...  1.597438e+09
# 49   Effectively using timeouts. #tiktoktherapist #...  1.603389e+09
# ..                                                 ...           ...
# 237  parenting 🫣 #timeout #parenting #singlemum #em...  1.759775e+09
# 35                                     October 5, 2025  1.759715e+09
# 155                               Reinforcing Behavior  1.759760e+09
# 287  Do Time-Outs Really Work with Kids? | Gentle P...  1.759924e+09
# 107  Kids do the darnest things😅❤️ @mummy.heaven  #...           NaN
#
#      view_count  like_count  comment_count  duration upload_date  \
# 63      24100.0      1598.0           33.0      31.0    20200629
# 249    895796.0     26607.0         1900.0      64.0    20200803
# 146     35600.0      2646.0          120.0      41.0    20200813
# 147     12600.0       468.0           28.0      26.0    20200814
# 49      78500.0      5890.0          206.0      57.0    20201022
# ..          ...         ...            ...       ...         ...
# 237       234.0        11.0            1.0      69.0    20251006
# 35          8.0         0.0            NaN      15.0    20251006
# 155        28.0         0.0            NaN      32.0    20251006
# 287       360.0         0.0            NaN      39.0    20251008
# 107         NaN         NaN            NaN       NaN        None
#
#                                            webpage_url
# 63   https://www.tiktok.com/@jennifer_nicole26/vide...
# 249        https://www.youtube.com/watch?v=yZjFQycWOck
# 146  https://www.tiktok.com/@preschooltherapy/video...
# 147  https://www.tiktok.com/@preschooltherapy/video...
# 49   https://www.tiktok.com/@preschooltherapy/video...
# ..                                                 ...
# 237  https://www.tiktok.com/@georgeox97/video/75581...
# 35         https://www.youtube.com/watch?v=YU675pDerFA
# 155        https://www.youtube.com/watch?v=A2zNQFlQI-E
# 287        https://www.youtube.com/watch?v=EToVYYeI3Ao
# 107  https://www.newsbreak.com/it-s-gone-viral--312...
#
# [293 rows x 32 columns]

# %%
df.extractor.value_counts()
# Out:
# extractor
# TikTok       174
# youtube       64
# Instagram     49
# facebook       3
# Pinterest      2
# generic        1
# Name: count, dtype: int64

# %%
df.sentiment.value_counts()
# Out:
# sentiment
# neutral     140
# negative    127
# positive     26
# Name: count, dtype: int64

# %%
df.to_excel("LLM_results.xlsx", index=False)
