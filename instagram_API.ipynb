# %%
import dotenv
import requests
dotenv.load_dotenv()
import os
import pandas as pd
from pprint import pprint
pd.set_option('display.max_columns', None)

# %%
r = requests.get("https://www.instagram.com/api/v1/fbsearch/web/top_serp/?enable_metadata=true&query=%23timeout&search_session_id=b35946c7-38bc-4103-8f4d-2cf7424b6181", headers={
    "accept": "*/*",
    "accept-language": "en-US,en;q=0.9,en-NZ;q=0.8",
    "cache-control": "no-cache",
    "pragma": "no-cache",
    "priority": "u=1, i",
    "sec-ch-prefers-color-scheme": "dark",
    "sec-ch-ua": "\"Chromium\";v=\"140\", \"Not=A?Brand\";v=\"24\", \"Microsoft Edge\";v=\"140\"",
    "sec-ch-ua-full-version-list": "\"Chromium\";v=\"140.0.7339.81\", \"Not=A?Brand\";v=\"24.0.0.0\", \"Microsoft Edge\";v=\"140.0.3485.54\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-model": "\"\"",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-ch-ua-platform-version": "\"10.0.0\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-asbd-id": "359341",
    "x-csrftoken": "zFEhY2dk6qY25si0DR0yilPwSj4AfONt",
    "x-ig-app-id": "936619743392459",
    "x-ig-www-claim": "hmac.AR0EtWVk63QqBzUInI-x3VQJd4fRSbj7n8Tw_CLxVtgzfUCr",
    "x-requested-with": "XMLHttpRequest",
    "x-web-session-id": "vlq5on:zakwi5:m7d5fi",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36 Edg/140.0.0.0",
    "cookie": os.getenv("IG_COOKIE")
})

# %%
"https://www.instagram.com/api/v1/fbsearch/web/top_serp/?enable_metadata=true&query=%23timeout&search_session_id=&next_max_id=7cf47f6c16024632a74b744cc9575ee8&rank_token=3f9b1f48-685e-429f-b9a8-91f9610276bd"
# Out:
# 'https://www.instagram.com/api/v1/fbsearch/web/top_serp/?enable_metadata=true&query=%23timeout&search_session_id=&next_max_id=7cf47f6c16024632a74b744cc9575ee8&rank_token=3f9b1f48-685e-429f-b9a8-91f9610276bd'

# %%
media_grid = r.json()['media_grid']
rank_token = media_grid["rank_token"]
next_max_id = media_grid["next_max_id"]

# %%
media = []
for section in media_grid["sections"]:
    for item in section["layout_content"]["medias"]:
        media.append(item["media"])
df = pd.json_normalize(media)
df
# Out:
#     caption_is_edited  device_timestamp  filter_type  has_shared_to_fb  \
# 0               False    17504538887240            0                 0
# 1               False  1752264246321863            0                 0
# 2               False  1754765627442524            0                 0
# 3               False   175517921351683            0                 0
# 4               False   240760908744197            0                 0
# 5               False    83553019973178            0                 0
# 6               False   174360368998601            0                 0
# 7               False  1732633738700805            0                 0
# 8               False  1759601770178668            0                 0
# 9               False   334153215265836            0                 0
# 10               True  1550786460769822            0                 0
# 11               True  1729812700190426            0                 0
# ...

# %%
df.to_csv("instagram_timeout.csv", index=False)

# %%
pprint(media[0])
# Out:
# {'are_remixes_crosspostable': True,
#  'boost_unavailable_identifier': None,
#  'boost_unavailable_reason': None,
#  'boost_unavailable_reason_v2': None,
#  'can_reply': False,
#  'can_see_insights_as_brand': False,
#  'can_viewer_reshare': True,
#  'can_viewer_save': True,
#  'caption': {'bit_flags': 0,
#              'content_type': 'comment',
#              'created_at': 1750454004,
#              'created_at_utc': 1750454004,
#              'did_report_as_spam': False,
#              'is_covered': False,
#              'is_ranked_comment': False,
#              'media_id': '3659394929518035992',
#              'pk': '18077094931927836',
#              'private_reply_status': 0,
#              'share_enabled': False,
#              'status': 'Active',
#              'strong_id__': '18077094931927836',
#              'text': 'You put Dalton in your room? #timeout#bitingchild#credit '
#                      '@ciarazanttt #oldersister#littlebrotherproblems',
# ...
